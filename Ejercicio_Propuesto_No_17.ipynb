# %% [markdown]
# <a href="https://colab.research.google.com/github/samuelvillegasc-cell/Ejercicio-Propuesto-No-17/blob/main/Ejercicio_Propuesto_No_17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Programa que calcula el área y la longitud de una circunferencia

# Paso 1: Ingresar radio
radio = float(input("Ingrese el radio del círculo: "))

# Paso 2: Calcular área
area = 3.1416 * radio * radio

# Paso 3: Calcular longitud
longitud = 2 * 3.1416 * radio

# Paso 4: Mostrar resultados
print("El área del círculo es:", area)
print("La longitud de la circunferencia es:", longitud)
# Out:
# Ingrese el radio del círculo: 20
# El área del círculo es: 1256.64
# La longitud de la circunferencia es: 125.664
